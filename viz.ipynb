# %%
import trimesh
import numpy as np

# %%
data = np.load("cached/103_decimated.npy")

# %%
data = data.astype(np.float16)

# %%
data.min(), data.max()
# Out:
# (0.0, 1.0)

# %%
data
# Out:
# array([[[[0.2522 , 0.926  , 0.413  ],
#          [0.2708 , 0.907  , 0.3225 ],
#          [0.2522 , 0.926  , 0.413  ],
#          ...,
#          [0.7383 , 0.8013 , 0.1797 ],
#          [0.7236 , 0.76   , 0.136  ],
#          [0.4583 , 0.507  , 0.998  ]],
#
#         [[0.2559 , 0.928  , 0.4158 ],
#          [0.155  , 0.8613 , 0.4814 ],
#          [0.2338 , 0.922  , 0.5303 ],
#          ...,
#          [0.768  , 0.7773 , 0.1816 ],
#          [0.7295 , 0.765  , 0.1434 ],
#          [0.2786 , 0.2715 , 0.8857 ]],
#
#         [[0.235  , 0.912  , 0.4011 ],
#          [0.4944 , 0.9707 , 0.3315 ],
#          [0.1624 , 0.8633 , 0.563  ],
#          ...,
#          [0.739  , 0.802  , 0.1807 ],
#          [0.7324 , 0.7227 , 0.883  ],
#          [0.819  , 0.8    , 0.2583 ]],
#
#         ...,
#
#         [[0.5967 , 0.825  , 0.1327 ],
#          [0.7266 , 0.7544 , 0.134  ],
#          [0.7256 , 0.733  , 0.1195 ],
#          ...,
#          [0.2438 , 0.2986 , 0.879  ],
# ...
